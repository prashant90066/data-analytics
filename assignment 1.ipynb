# %% [markdown]
# # representation of pie chart

# %%
" enter number of students in each branch"
    {
        cse = readline("Enter number of students in cse : "); 
        cst = readline("Enter number of students in cst  : "); 
        ece = readline("Enter number of students in ece : "); 
        mech = readline("Enter number of students in mech : ");
        bio = readline("Enter number of students in bio: ");
    }

    cse = as.integer(cse); 
    cst = as.integer(cst); 
    ece = as.integer(ece); 
    mech = as.integer(mech);
    bio = as.integer(bio);

    sum = cse+cst+ece+mech+bio;
    "sum of all students "
    sum;

    CSE=(cse/sum)*100;
    CSE;
    CST=(cst/sum)*100;
    CST;
    ECE=(ece/sum)*100;
    ECE;
    MECH=(mech/sum)*100;
    MECH;
    BIO=(bio/sum)*100;
    BIO;


# Create a vector of pies
x <- c(CSE,CST,ECE,MECH,BIO)



# Create a vector of labels
mylabel <- c("CSE", "CST", "ECE", "MECH","BIO")

# Display the pie chart with labels
pie(x, label = mylabel, main = "BRANCHES")
# Out:
# [1] " enter number of students in each branch"
# Enter number of students in cse : 140
# Enter number of students in cst  : 45
# Enter number of students in ece : 75
# Enter number of students in mech : 65
# Enter number of students in bio: 35
# [1] "sum of all students "
# [1] 360
# [1] 38.88889
# [1] 12.5
# [1] 20.83333
# [1] 18.05556
# [1] 9.722222
# Plot with title "BRANCHES"

# %% [markdown]
# # representation in bar graph

# %%
sales<- c(1250,1325,1275,1175,1350)
year <- c("2010","2011","2012","2013","2014")


# Plot the bar chart 
barplot(sales,names.arg=year,purchase,xlab="year",ylab="sales",col="blue",
main="Revenue chart",border="red");

# Save the file
dev.off()
# Out:
# png
#   3
# Plot with title "Revenue chart"

# %%
purchase<- c(1350,1375,1450,1450,1475)
year <- c("2010","2011","2012","2013","2014")


# Plot the bar chart 
barplot(sales,names.arg=year,purchase,xlab="year",ylab="purchase",col="blue",
main="Revenue chart",border="red");

# Save the file
dev.off()
# Out:
# png
#   3
# Plot with title "Revenue chart"
